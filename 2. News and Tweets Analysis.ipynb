# %% [markdown]
# # Imports and installings

# %%
# !pip install textblob 
# !pip install snscrape
# !pip install beautifulsoup4
# !pip install stopwords
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\blure\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\blure\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.3.15)
# Requirement already satisfied: tqdm in c:\users\blure\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.0)
# Requirement already satisfied: click in c:\users\blure\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\blure\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: colorama in c:\users\blure\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # NewsApi articles
# With NewsApi lets get articles that match the search query within the last 30 days with 1 or more keywords

# %%
# set the API endpoint and parameters
url = 'https://newsapi.org/v2/everything'
params = {
    'q': 'the',
    'pageSize': 100,  # max is 100
    'language': 'en',
    'apiKey': 'bb4146fab2c74552ad299e0d0f4028fa'
}

# send the first GET request to get the total number of results
params['page'] = 1
response = requests.get(url, params=params)
json_data = response.json()

# retrieve all the articles by making multiple requests with a loop
articles = []
if json_data.get('articles'):
    for page in range(1, (json_data['totalResults'] // 200) + 2):
        params['page'] = page
        response = requests.get(url, params=params)
        json_data = response.json()
        if json_data.get('articles'):
            for article in json_data['articles']:
                # perform sentiment analysis on the article content
                content = article['content']
                if content is not None:
                    blob = TextBlob(content)
                    sentiment_score = blob.sentiment.polarity
                else:
                    sentiment_score = None

                articles.append({
                    'title': article['title'],
                    'date': article['publishedAt'],
                    'content': content,
                    'publisher': article['source']['name'],
                    'sentiment_score': sentiment_score
                })
        else:
            break

# create a pandas dataframe with the articles list
if articles:
    df = pd.DataFrame(articles)
    
else:
    print('No articles found for the given search query and parameters.')

# %%
df
# Out:
#                                                 title                  date  \
# 0             This Is the Lightest Paint in the World  2023-03-22T11:00:00Z
# 1   The Apple Watch SE drops to its lowest price y...  2023-03-17T16:45:28Z
# 2   The Out-of-Touch Adults' Guide to Kid Culture:...  2023-04-07T15:00:00Z
# 3   Imploring TikTok to “Think of the Children” Mi...  2023-03-25T11:00:00Z
# 4        The Dangerous Weak Link in the US Food Chain  2023-04-06T12:00:00Z
# ..                                                ...                   ...
# 95  The 1TB Samsung T7 portable SSD drops to a rec...  2023-03-14T20:00:30Z
# 96  New Zealand is the latest country to ban TikTo...  2023-03-17T14:35:39Z
# 97  TikTok CEO says selling the app won't satisfy ...  2023-03-16T15:37:17Z
# 98  The Morning After: Xbox's mobile game store co...  2023-03-21T11:20:26Z
# 99  A TikTok ban is a lot more complicated than ju...  2023-03-21T20:11:14Z
#
#                                               content       publisher  \
# 0   Dayna Baumeister, codirector of Arizona State ...           Wired
# 1   All products recommended by Engadget are selec...        Engadget
# 2   This weeks Out-of-Touch Adults Guide explores ...  Lifehacker.com
# 3   nearly every Congressional hearing on Big Tech...           Wired
# 4   Just-in-time logistics mean that even short-te...           Wired
# ..                                                ...             ...
# 95  All products recommended by Engadget are selec...        Engadget
# 96  New Zealand has joined the growing list of cou...        Engadget
# 97  TikTok\r\n CEO Shou Zi Chew has claimed that, ...        Engadget
# 98  Microsoft could launch an Xbox store on iOS an...        Engadget
# 99  Disentangling ourselves from TikTok is more co...        Engadget
#
#     sentiment_score
# 0          0.122222
# 1          0.000000
# 2          0.200000
# 3          0.150000
# 4         -0.322917
# ..              ...
# 95         0.000000
# 96         0.175325
# 97         0.000000
# 98         0.087500
# 99         0.027273
#
# [100 rows x 5 columns]

# %%
df['content'][4] #we can see that we have the full article
# Out:
# 'Just-in-time logistics mean that even short-term cyberattacks\xa0can have serious consequences.\xa0Hacks that disrupt fertilizer or pesticide production can force farmers to sit out planting seasons. Breac… [+3255 chars]'

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# some stopwords to be removed (because i already seen the image and it had them but they're useless)
stopwords = set(['the', 'and','is'])

# preprocess the text data by removing the stopwords
text_column = df['content']
text = ' '.join(text_column.apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stopwords])))

wordcloud = WordCloud(width=1500, height=1000, background_color='white').generate(text)

fig, ax = plt.subplots(figsize=(15, 10))

# plot the wordcloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# The News API limits the number of results that can be returned in a single request to 100. However, we can use pagination to retrieve additional results beyond the first 100. but since the results go up to 1 month this doesnt change the ouptup since the articles in that period are limited

# %%
# set the API endpoint and parameters
url = 'https://newsapi.org/v2/everything'
params = {
    'q': 'cancer AND air pollution',
    'pageSize': 100,
    'language': 'en',
    'apiKey': 'bb4146fab2c74552ad299e0d0f4028fa'
}

# send the first GET request to get the total number of results
params['page'] = 1
response = requests.get(url, params=params)
json_data = response.json()

# retrieve all the articles by making multiple requests with a loop
articles = []
if json_data.get('articles'):
    for page in range(1, (json_data['totalResults'] // 100) + 2):
        params['page'] = page
        response = requests.get(url, params=params)
        json_data = response.json()
        if json_data.get('articles'):
            for article in json_data['articles']:
                # perform sentiment analysis on the article content
                content = article['content']
                if content is not None:
                    blob = TextBlob(content)
                    sentiment_score = blob.sentiment.polarity
                else:
                    sentiment_score = None

                articles.append({
                    'title': article['title'],
                    'date': article['publishedAt'],
                    'content': content,
                    'publisher': article['source']['name'],
                    'sentiment_score': sentiment_score
                })
        else:
            break

# create a pandas dataframe with the articles list
if articles:
    df = pd.DataFrame(articles)

    # print the dataframe
    df
else:
    print('No articles found for the given search query and parameters.')

# %%
df
# Out:
#                                                 title                  date  \
# 0   You Are What You Breathe. How to Test Your Hom...  2023-03-14T20:43:55Z
# 1   Climate emergency is the biggest health crisis...  2023-04-10T14:57:29Z
# 2   'Cancer Alley' at center of lawsuit claiming e...  2023-03-23T12:21:37Z
# 3   EPA cracks down on 'forever chemicals' in tap ...  2023-03-14T14:44:43Z
# 4   Air pollution’s role in the promotion of lung ...  2023-04-05T00:00:00Z
# ..                                                ...                   ...
# 95  Ozone-depleting CFC chemicals are making an al...  2023-04-04T10:36:24Z
# 96  Millions of Americans Could Be Unknowingly Liv...  2023-04-05T10:00:00Z
# 97  The EPA Is Finally Going to Limit Forever Chem...  2023-03-14T18:35:00Z
# 98  The Glioblastoma Multiforme (GBM) Treatment Ma...  2023-04-13T09:31:00Z
# 99  Protein Chip Market Size to Reach USD 3.07 Bil...  2023-03-16T16:36:00Z
#
#                                               content            publisher  \
# 0   Air pollution can be easy to ignore from day t...                 Time
# 1   The latest Intergovernmental Panel on Climate ...         The Guardian
# 2   The residents of a Louisiana parish, located i...             ABC News
# 3   PFAS, or "forever chemicals," are an increasin...     Business Insider
# 4   <li>Hill, W. et al.Nature616, 159167 (2023).\r...           Nature.com
# ..                                                ...                  ...
# 95  Sign up to the Independent Climate email for t...          Independent
# 96  American Lung Association launches campaign to...  Yahoo Entertainment
# 97  The U.S. Environmental Protection Agency annou...    Gizmodo Australia
# 98  The Business Research Company's global market ...  Yahoo Entertainment
# 99  The market for protein chips is growing, given...  Yahoo Entertainment
#
#     sentiment_score
# 0          0.074306
# 1         -0.166667
# 2          0.000000
# 3          0.000000
# 4          0.000000
# ..              ...
# 95         0.220000
# 96         0.033333
# 97         0.000000
# 98         0.250000
# 99         0.000000
#
# [100 rows x 5 columns]

# %% [markdown]
# # Web Scraping
# Because of NewsApi Limitations of the free subscription we tried to change approach to get the articles  and tweets data
# Indeed I used a scraping service APIFY(https://apify.com/) since by doing the normal scraping I could only get 100 articles a time and always the same ones, and to do scraping with twitter you need to use their API(but the policies recently change so we didnt manage to get the accounts approved). The bad thing about  apify is that from google news I could get only the title and not the entire article, and for the tweets theres no possibility to specify the language.

# %%
#the keywords to search were air pollution and cancer

a= pd.read_csv('dataset_google-news-scraper_2023-04-15_11-57-57-994.csv') #cancer articles
b= pd.read_csv('dataset_google-news-scraper_2023-04-15_12-25-06-068.csv') #air pollution

# concatenate the two dataframes into a single dataframe
df = pd.concat([a, b])

df
# Out:
#                                                     link  \
# 0      https://news.google.com/rss/articles/CBMidGh0d...
# 1      https://news.google.com/rss/articles/CBMidWh0d...
# 2      https://news.google.com/rss/articles/CBMilwFod...
# 3      https://news.google.com/rss/articles/CBMiWGh0d...
# 4      https://news.google.com/rss/articles/CBMicWh0d...
# ...                                                  ...
# 97970  https://news.google.com/rss/articles/CBMidWh0d...
# 97971  https://news.google.com/rss/articles/CBMiUGh0d...
# 97972  https://news.google.com/rss/articles/CBMipAFod...
# 97973  https://news.google.com/rss/articles/CBMiLGh0d...
# 97974  https://news.google.com/rss/articles/CBMiXmh0d...
#
#                     publishedAt                       source  \
# 0      2022-12-26T08:00:00.000Z                    USA TODAY
# 1      2022-10-31T07:00:00.000Z                The ASCO Post
# 2      2022-11-17T08:00:00.000Z                The ASCO Post
# 3      2022-12-26T08:00:00.000Z               New York Post
# 4      2022-12-08T08:00:00.000Z          The Times of Israel
# ...                         ...                          ...
# 97970  2020-11-05T08:00:00.000Z                Worcester Mag
# 97971  2020-11-05T08:00:00.000Z  Home of the Olympic Channel
# 97972  2020-11-05T08:00:00.000Z              Courier & Press
# 97973  2020-11-05T08:00:00.000Z                   SHINE News
# 97974  2020-11-05T08:00:00.000Z                   TechCrunch
#
#                                                    title
# 0      Blood pressure tablets recalled over potential...
# 1      Neoadjuvant Immunotherapy With Relatlimab and ...
# 2      Dabrafenib in Combination With Trametinib for ...
# 3      Kansas cops raid terminally ill patient's hosp...
# 4      2 common drugs may help protect against second...
# ...                                                  ...
# 97970           Bald eagles of Worcester county are back
# 97971      2020 Vuelta a Espana TV, live stream schedule
# 97972  Former USI head coach Rodney Watson to join So...
# 97973  Takeda returns to CIIE, commits to China - SHI...
# 97974  Amazon launches its first Amazon Air regional ...
#
# [195743 rows x 4 columns]

# %% [markdown]
# # Articles Analysis

# %%
from wordcloud import WordCloud, STOPWORDS

# concatenate all the strings in the column
text = ' '.join(df['title'])

# create a set of stopwords
stopwords = set(STOPWORDS)

# add a specific word to the set of stopwords
stopwords.add('New')
stopwords.add('say')
stopwords.add('will')
stopwords.add('s')


# generate the wordcloud
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(text)

# plot the wordcloud
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show()

# %%
top_10_counts=df['source'].value_counts().head(15) #lets see who are the most active publishers regarding the air pollution and cancer topics

# %%
# Plotting histogram
plt.figure(figsize=(10, 6)) # Set the figure size
plt.bar(top_10_counts.index, top_10_counts.values, color='#009999') # Create a bar plot
plt.xlabel('Source') # Set the x-axis label
plt.ylabel('Articles published') # Set the y-axis label
plt.title('Top 15 Sources by coverage') # Set the title of the plot
plt.xticks(rotation=90) # Rotate x-axis labels for better readability
plt.show() # Display the plot
plt.savefig('histogram.png', dpi=300, bbox_inches='tight') # Save the figure with white background

# %%
from textblob import TextBlob

def get_sentiment(text):
    """
    Returns the sentiment polarity of the given text as a float between -1 (bad) and 1(good).
    """
    blob = TextBlob(text)
    return blob.sentiment.polarity
# Apply sentiment analysis function to title column
df['title_sentiment'] = df['title'].apply(get_sentiment)

# %%
df
# Out:
#                                                     link  \
# 0      https://news.google.com/rss/articles/CBMidGh0d...
# 1      https://news.google.com/rss/articles/CBMidWh0d...
# 2      https://news.google.com/rss/articles/CBMilwFod...
# 3      https://news.google.com/rss/articles/CBMiWGh0d...
# 4      https://news.google.com/rss/articles/CBMicWh0d...
# ...                                                  ...
# 97970  https://news.google.com/rss/articles/CBMidWh0d...
# 97971  https://news.google.com/rss/articles/CBMiUGh0d...
# 97972  https://news.google.com/rss/articles/CBMipAFod...
# 97973  https://news.google.com/rss/articles/CBMiLGh0d...
# 97974  https://news.google.com/rss/articles/CBMiXmh0d...
#
#                     publishedAt                       source  \
# 0      2022-12-26T08:00:00.000Z                    USA TODAY
# 1      2022-10-31T07:00:00.000Z                The ASCO Post
# 2      2022-11-17T08:00:00.000Z                The ASCO Post
# 3      2022-12-26T08:00:00.000Z               New York Post
# 4      2022-12-08T08:00:00.000Z          The Times of Israel
# ...                         ...                          ...
# 97970  2020-11-05T08:00:00.000Z                Worcester Mag
# 97971  2020-11-05T08:00:00.000Z  Home of the Olympic Channel
# 97972  2020-11-05T08:00:00.000Z              Courier & Press
# 97973  2020-11-05T08:00:00.000Z                   SHINE News
# 97974  2020-11-05T08:00:00.000Z                   TechCrunch
#
#                                                    title  title_sentiment
# 0      Blood pressure tablets recalled over potential...         0.000000
# 1      Neoadjuvant Immunotherapy With Relatlimab and ...         0.000000
# 2      Dabrafenib in Combination With Trametinib for ...         0.000000
# 3      Kansas cops raid terminally ill patient's hosp...        -0.500000
# 4      2 common drugs may help protect against second...        -0.283333
# ...                                                  ...              ...
# 97970           Bald eagles of Worcester county are back         0.000000
# 97971      2020 Vuelta a Espana TV, live stream schedule         0.136364
# 97972  Former USI head coach Rodney Watson to join So...         0.000000
# 97973  Takeda returns to CIIE, commits to China - SHI...         0.000000
# 97974  Amazon launches its first Amazon Air regional ...         0.250000
#
# [195743 rows x 5 columns]

# %%
# Create histogram of title_sentiment column
plt.hist(df['title_sentiment'], bins=10)

# Add labels and title to plot
plt.xlabel('Sentiment Value')
plt.ylabel('Count')
plt.title('Distribution of Title Sentiment')

# Show plot
plt.show()

# %% [markdown]
# Lets compare the sentiment from tweets, the tweets where scraped by using APIFY, the input were 2 keywords air pollution and cancer

# %%
tweet=pd.read_csv('dataset_twitter-scraper_2023-04-15_11-50-57-970.csv')
# Out:
# C:\Users\blure\AppData\Local\Temp\ipykernel_15776\2301912888.py:1: DtypeWarning: Columns (32,33,34,42,48,51,66,67,68,69,70,71,72,73,74,75,76,77,81,85,88,91,92,96,97,98,99,107,108,109,110,111,112,113,114,115,137,138,139,141,142,143,145,146,147,149,150,151,153,154,155,157,158,159,161,162,163,165,166,167,178,179,180,181,182,183,184,185,196,197,198,199,200,201,263,264,265,267,268,269,271,272,273,275,276,277,279,280,281,283,284,285,287,288,289,291,292,293,295,296,297,299,300,301,303,304,305,307,308,309,311,312,313,315,316,317,319,320,321,323,324,325,327,328,329,331,332,333,335,336,337,339,340,341,343,344,345,347,348,349,351,352,353,355,356,357,359,360,361,363,364,365,367,368,369,371,372,373,375,376,377,379,380,381,383,384,385,387,388,389,391,392,393,395,396,397) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweet=pd.read_csv('dataset_twitter-scraper_2023-04-15_11-50-57-970.csv')

# %%
tweet
# Out:
#           conversation_id                created_at  favorite_count  \
# 0     1647191988771647490  2023-04-15T10:55:48.000Z               0
# 1     1647191968529915905  2023-04-15T10:55:43.000Z               0
# 2     1647191854876880896  2023-04-15T10:55:16.000Z               0
# 3     1647190908951994368  2023-04-15T10:51:30.000Z               0
# 4     1647188135703396355  2023-04-15T10:40:29.000Z               1
# ...                   ...                       ...             ...
# 9995  1644034789098258437  2023-04-06T17:50:13.000Z               2
# 9996  1644034257642221571  2023-04-06T17:48:06.000Z               0
# 9997  1644033562818015243  2023-04-06T17:45:20.000Z               0
# 9998  1643916821295243264  2023-04-06T10:01:27.000Z             179
# 9999  1643831943409070082  2023-04-06T04:24:10.000Z            1456
#
#                                               full_text  hashtags/0  \
# 0               Help our friend stay alive!!! 😤 #Cancer      Cancer
# 1     Should we fight the propaganda of Nandini vs A...   bournvita
# 2     https://t.co/KbQ9oXSg6R\ndeveloped #degrader #...    degrader
# 3     “Million-year-old #viruses help fight #cancer,...     viruses
# 4     #CiudadReal Esto se ha de hacer con el alma......  CiudadReal
# ...                                                 ...         ...
# 9995  At my 6-month checkup, it wasn’t good news. Su...      memoir
# 9996  Hugh Jackman da negativo ante el riesgo de cán...      CÁNCER
# 9997  @LucyB_Tacos Anti #Cancer #TACOS are the best ...      Cancer
# 9998  Malia Obama to Direct Her First Short Film Und...         NaN
# 9999  Message from Chairman SKMT, Imran Khan, on how...       zakat
#
#                  hashtags/1     hashtags/2 hashtags/3 hashtags/4   hashtags/5  \
# 0                       NaN            NaN        NaN        NaN          NaN
# 1                     sugar         cancer   immunity       fake          NaN
# 2                 molecules          DEG35      DEG77   proteins       cancer
# 3                    cancer     scientists        NaN        NaN          NaN
# 4                      DEMI         cáncer      ciega        NaN          NaN
# ...                     ...            ...        ...        ...          ...
# 9995             Overcoming           FREE   Survival    Triumph  Divorcelady
# 9996                   PIEL            NaN        NaN        NaN          NaN
# 9997                  TACOS       AllicinV        NaN        NaN          NaN
# 9998                    NaN            NaN        NaN        NaN          NaN
# 9999  EasetheBurdenofCancer  ZakatforSKMCH     cancer      SKMCH          NaN
#
#       ... user_mentions/46/screen_name user_mentions/47/id_str  \
# 0     ...                          NaN                     NaN
# 1     ...                          NaN                     NaN
# 2     ...                          NaN                     NaN
# 3     ...                          NaN                     NaN
# 4     ...                          NaN                     NaN
# ...   ...                          ...                     ...
# 9995  ...                          NaN                     NaN
# 9996  ...                          NaN                     NaN
# 9997  ...                          NaN                     NaN
# 9998  ...                          NaN                     NaN
# 9999  ...                          NaN                     NaN
#
#      user_mentions/47/name user_mentions/47/profile  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
# ...                    ...                      ...
# 9995                   NaN                      NaN
# 9996                   NaN                      NaN
# 9997                   NaN                      NaN
# 9998                   NaN                      NaN
# 9999                   NaN                      NaN
#
#      user_mentions/47/screen_name user_mentions/48/id_str  \
# 0                             NaN                     NaN
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3                             NaN                     NaN
# 4                             NaN                     NaN
# ...                           ...                     ...
# 9995                          NaN                     NaN
# 9996                          NaN                     NaN
# 9997                          NaN                     NaN
# 9998                          NaN                     NaN
# 9999                          NaN                     NaN
#
#      user_mentions/48/name user_mentions/48/profile  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
# ...                    ...                      ...
# 9995                   NaN                      NaN
# 9996                   NaN                      NaN
# 9997                   NaN                      NaN
# 9998                   NaN                      NaN
# 9999                   NaN                      NaN
#
#      user_mentions/48/screen_name view_count
# 0                             NaN        NaN
# 1                             NaN        NaN
# 2                             NaN        NaN
# 3                             NaN        3.0
# 4                             NaN       16.0
# ...                           ...        ...
# 9995                          NaN       79.0
# 9996                          NaN       12.0
# 9997                          NaN       29.0
# 9998                          NaN     9846.0
# 9999                          NaN    82379.0
#
# [10000 rows x 399 columns]

# %%
# concatenate all the strings in the column
text = ' '.join(tweet['full_text'])

# create a set of stopwords
stopwords = set(STOPWORDS)

# add a specific word to the set of stopwords
stopwords.add('New')
stopwords.add('co')
stopwords.add('t')
stopwords.add('https')


# generate the wordcloud
wordcloudtweet = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(text)

# plot the wordcloud
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloudtweet) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show()
#we can see that the results are not insightful because part of the tweets were about ...

# %%
tweet['title_sentiment'] = tweet['full_text'].apply(get_sentiment)

# %%
tweet
# Out:
#           conversation_id                created_at  favorite_count  \
# 0     1647191988771647490  2023-04-15T10:55:48.000Z               0
# 1     1647191968529915905  2023-04-15T10:55:43.000Z               0
# 2     1647191854876880896  2023-04-15T10:55:16.000Z               0
# 3     1647190908951994368  2023-04-15T10:51:30.000Z               0
# 4     1647188135703396355  2023-04-15T10:40:29.000Z               1
# ...                   ...                       ...             ...
# 9995  1644034789098258437  2023-04-06T17:50:13.000Z               2
# 9996  1644034257642221571  2023-04-06T17:48:06.000Z               0
# 9997  1644033562818015243  2023-04-06T17:45:20.000Z               0
# 9998  1643916821295243264  2023-04-06T10:01:27.000Z             179
# 9999  1643831943409070082  2023-04-06T04:24:10.000Z            1456
#
#                                               full_text  hashtags/0  \
# 0               Help our friend stay alive!!! 😤 #Cancer      Cancer
# 1     Should we fight the propaganda of Nandini vs A...   bournvita
# 2     https://t.co/KbQ9oXSg6R\ndeveloped #degrader #...    degrader
# 3     “Million-year-old #viruses help fight #cancer,...     viruses
# 4     #CiudadReal Esto se ha de hacer con el alma......  CiudadReal
# ...                                                 ...         ...
# 9995  At my 6-month checkup, it wasn’t good news. Su...      memoir
# 9996  Hugh Jackman da negativo ante el riesgo de cán...      CÁNCER
# 9997  @LucyB_Tacos Anti #Cancer #TACOS are the best ...      Cancer
# 9998  Malia Obama to Direct Her First Short Film Und...         NaN
# 9999  Message from Chairman SKMT, Imran Khan, on how...       zakat
#
#                  hashtags/1     hashtags/2 hashtags/3 hashtags/4   hashtags/5  \
# 0                       NaN            NaN        NaN        NaN          NaN
# 1                     sugar         cancer   immunity       fake          NaN
# 2                 molecules          DEG35      DEG77   proteins       cancer
# 3                    cancer     scientists        NaN        NaN          NaN
# 4                      DEMI         cáncer      ciega        NaN          NaN
# ...                     ...            ...        ...        ...          ...
# 9995             Overcoming           FREE   Survival    Triumph  Divorcelady
# 9996                   PIEL            NaN        NaN        NaN          NaN
# 9997                  TACOS       AllicinV        NaN        NaN          NaN
# 9998                    NaN            NaN        NaN        NaN          NaN
# 9999  EasetheBurdenofCancer  ZakatforSKMCH     cancer      SKMCH          NaN
#
#       ... user_mentions/47/id_str user_mentions/47/name  \
# 0     ...                     NaN                   NaN
# 1     ...                     NaN                   NaN
# 2     ...                     NaN                   NaN
# 3     ...                     NaN                   NaN
# 4     ...                     NaN                   NaN
# ...   ...                     ...                   ...
# 9995  ...                     NaN                   NaN
# 9996  ...                     NaN                   NaN
# 9997  ...                     NaN                   NaN
# 9998  ...                     NaN                   NaN
# 9999  ...                     NaN                   NaN
#
#      user_mentions/47/profile user_mentions/47/screen_name  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 9995                      NaN                          NaN
# 9996                      NaN                          NaN
# 9997                      NaN                          NaN
# 9998                      NaN                          NaN
# 9999                      NaN                          NaN
#
#      user_mentions/48/id_str user_mentions/48/name user_mentions/48/profile  \
# 0                        NaN                   NaN                      NaN
# 1                        NaN                   NaN                      NaN
# 2                        NaN                   NaN                      NaN
# 3                        NaN                   NaN                      NaN
# 4                        NaN                   NaN                      NaN
# ...                      ...                   ...                      ...
# 9995                     NaN                   NaN                      NaN
# 9996                     NaN                   NaN                      NaN
# 9997                     NaN                   NaN                      NaN
# 9998                     NaN                   NaN                      NaN
# 9999                     NaN                   NaN                      NaN
#
#      user_mentions/48/screen_name view_count title_sentiment
# 0                             NaN        NaN        0.195312
# 1                             NaN        NaN       -0.200000
# 2                             NaN        NaN       -0.185185
# 3                             NaN        3.0        0.000000
# 4                             NaN       16.0        0.000000
# ...                           ...        ...             ...
# 9995                          NaN       79.0        0.580000
# 9996                          NaN       12.0        0.000000
# 9997                          NaN       29.0        0.800000
# 9998                          NaN     9846.0        0.121591
# 9999                          NaN    82379.0        0.000000
#
# [10000 rows x 400 columns]

# %%
# Create histogram of title_sentiment column
plt.hist(tweet['title_sentiment'], bins=10)

# Add labels and title to plot
plt.xlabel('Sentiment Value')
plt.ylabel('Count')
plt.title('Distribution of Title Sentiment')

# Show plot
plt.show()

# %% [markdown]
# Now that we have found that there's public intrest concerns in the health and pollution in the next notebooks we will work more on the predictions
